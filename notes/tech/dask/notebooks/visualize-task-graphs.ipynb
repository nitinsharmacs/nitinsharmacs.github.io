# %%
import dask.array as da
import dask

# %%
x = da.ones((15, 15), chunks=(5, 5))

# %%
y = x.sum()

# %%
dask.visualize(y)

# %%
y.visualize(rankdir='BT')

# %%
dask.visualize(y, optimize_graph=True)

# %% [markdown]
# ## Visualize High level dask graph

# %%
y.dask.visualize(filename='test.svg')

# %% [markdown]
# ## High level graph HTML representation

# %%
y.dask
# Out:
# HighLevelGraph with 4 layers.
# <dask.highlevelgraph.HighLevelGraph object at 0x10e041330>
#  0. ones_like-44817800100989a0a789e6d1be702b8f
#  1. sum-1eee5d86c351bbfd9246db6fcdd2ab33
#  2. sum-partial-0259629db3a875f0182cc02372216a68
#  3. sum-aggregate-00894334ef002abf8d298cbe8aa1aab4
